# %% [markdown]
# # YouTube Data API Project

# %% [markdown]
# This script collects and analyzes data from the YouTube channel "WildLens" using the YouTube Data API v3.
# It retrieves channel statistics, video details (like view count, likes, etc.), and performs various analyses
# on the collected data.

# %%
api_key = "YOUR_API_KEY"

# %%
channel_ids = ['UCf1XIplYiqNv9baGsFHwPPQ']

# %% [markdown]
# ## Data collection

# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON

# %%
# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client

youtube = build(api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
get_channel_stats(youtube, channel_ids)
# Out:
#          channelName subscribers      views totalVideos  \
# 0  WildLens by Abrar     1670000  329891631         493
#
#                  playlistId
# 0  UUf1XIplYiqNv9baGsFHwPPQ

# %%
playlist_id = "UUf1XIplYiqNv9baGsFHwPPQ"

# %%
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
def get_video_details(youtube, video_ids):
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }

            video_info = {}
            video_info['video_id'] = video['id']

            # print(video_info)
            # print(stats_to_keep.keys())

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)

# %% [markdown]
# ## Data Pre-processing

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']

# %%
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
video_df.dtypes
# Out:
# video_id           object
# channelTitle       object
# title              object
# description        object
# tags               object
# publishedAt        object
# viewCount           int64
# likeCount           int64
# favouriteCount    float64
# commentCount        int64
# duration           object
# definition         object
# caption            object
# dtype: object

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_df
# Out:
#         video_id       channelTitle  \
# 0    imT2c4Efoxc  WildLens by Abrar
# 1    kVqAeo6k6b0  WildLens by Abrar
# 2    VkKRL-QMdm0  WildLens by Abrar
# 3    YufZFo44fOg  WildLens by Abrar
# 4    vsmkR_DAfjY  WildLens by Abrar
# ..           ...                ...
# 489  kWoEs6vNO94  WildLens by Abrar
# 490  8jcxfV3zarE  WildLens by Abrar
# 491  jbPyvT78XMQ  WildLens by Abrar
# 492  7vganh6--M8  WildLens by Abrar
# 493  lJv4UMQOcTw  WildLens by Abrar
#
#                                                  title  \
# 0    My Nightmare Experience with Lahore Airport Cu...
# 1    Traveling Around The World on Bike #wildlensby...
# 2    Cape of Good Hope and End of Africa Series 🇿🇦 ...
# 3    Finally Arrived in Cape Town the Most Beautifu...
# 4    The Journey is Getting tough as I get Closer t...
# ..                                                 ...
# 489                             Hallstatt Austria Vlog
# 490  Lapland one last Arctic Adventure Vlog 04 (Urd...
# 491  Lapland Chasing the dream (part 03) Vlog 03 | ...
# 492  Lapland Winter Wilderness Adventure (Part 02) ...
# 493        Lapland Winter Wonderland (part 01) Vlog 01
#
#                                            description  \
# 0    Instagram: https://www.instagram.com/WildLensB...
# 1    Imagine a life bursting with color – new skill...
# 2    Instagram: https://www.instagram.com/WildLensB...
# 3    Instagram: https://www.instagram.com/WildLensB...
# 4    Instagram: https://www.instagram.com/WildLensB...
# ..                                                 ...
# 489  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 490  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 491  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 492  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 493  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 489  [Hallstatt, Austria, Salzburg, Hallstatt Austr...
# 490  [Lapland, Finland, Lapland finland, lapland tr...
# 491  [Finland, Lapland, Lapland finland, Riisituntu...
# 492  [Lapland, Finland, Pakistanivlogger, Urduvlogs...
# 493  [Lapland, Finland, Syote, Urduvlogs, winter, p...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-06-23 14:46:43+00:00     614215      24110             NaN
# 1   2024-05-24 14:00:38+00:00     128516      13678             NaN
# 2   2024-05-12 16:12:00+00:00     389447      25511             NaN
# 3   2024-05-10 15:30:41+00:00     328525      16764             NaN
# 4   2024-05-07 16:03:07+00:00     281947      16116             NaN
# ..                        ...        ...        ...             ...
# 489 2019-02-14 10:36:48+00:00      59320       3793             NaN
# 490 2019-01-27 09:48:43+00:00      52570       2972             NaN
# 491 2019-01-19 12:18:06+00:00      68160       3753             NaN
# 492 2019-01-13 00:02:52+00:00      85857       4122             NaN
# 493 2019-01-06 16:50:35+00:00     180960       8832             NaN
#
#      commentCount  duration definition caption pushblishDayName
# 0            3699  PT29M51S         hd    true           Sunday
# 1             480      PT1M         hd   false           Friday
# 2            3011   PT29M8S         hd    true           Sunday
# 3             789  PT23M51S         hd    true           Friday
# 4             665  PT24M53S         hd    true          Tuesday
# ..            ...       ...        ...     ...              ...
# 489           177    PT6M9S         hd   false         Thursday
# 490           168    PT7M4S         hd   false           Sunday
# 491           208  PT10M10S         hd   false         Saturday
# 492           205   PT9M42S         hd   false           Sunday
# 493           514   PT8M18S         hd   false           Sunday
#
# [494 rows x 14 columns]

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df
# Out:
#         video_id       channelTitle  \
# 0    imT2c4Efoxc  WildLens by Abrar
# 1    kVqAeo6k6b0  WildLens by Abrar
# 2    VkKRL-QMdm0  WildLens by Abrar
# 3    YufZFo44fOg  WildLens by Abrar
# 4    vsmkR_DAfjY  WildLens by Abrar
# ..           ...                ...
# 489  kWoEs6vNO94  WildLens by Abrar
# 490  8jcxfV3zarE  WildLens by Abrar
# 491  jbPyvT78XMQ  WildLens by Abrar
# 492  7vganh6--M8  WildLens by Abrar
# 493  lJv4UMQOcTw  WildLens by Abrar
#
#                                                  title  \
# 0    My Nightmare Experience with Lahore Airport Cu...
# 1    Traveling Around The World on Bike #wildlensby...
# 2    Cape of Good Hope and End of Africa Series 🇿🇦 ...
# 3    Finally Arrived in Cape Town the Most Beautifu...
# 4    The Journey is Getting tough as I get Closer t...
# ..                                                 ...
# 489                             Hallstatt Austria Vlog
# 490  Lapland one last Arctic Adventure Vlog 04 (Urd...
# 491  Lapland Chasing the dream (part 03) Vlog 03 | ...
# 492  Lapland Winter Wilderness Adventure (Part 02) ...
# 493        Lapland Winter Wonderland (part 01) Vlog 01
#
#                                            description  \
# 0    Instagram: https://www.instagram.com/WildLensB...
# 1    Imagine a life bursting with color – new skill...
# 2    Instagram: https://www.instagram.com/WildLensB...
# 3    Instagram: https://www.instagram.com/WildLensB...
# 4    Instagram: https://www.instagram.com/WildLensB...
# ..                                                 ...
# 489  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 490  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 491  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 492  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 493  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 489  [Hallstatt, Austria, Salzburg, Hallstatt Austr...
# 490  [Lapland, Finland, Lapland finland, lapland tr...
# 491  [Finland, Lapland, Lapland finland, Riisituntu...
# 492  [Lapland, Finland, Pakistanivlogger, Urduvlogs...
# 493  [Lapland, Finland, Syote, Urduvlogs, winter, p...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-06-23 14:46:43+00:00     614215      24110             NaN
# 1   2024-05-24 14:00:38+00:00     128516      13678             NaN
# 2   2024-05-12 16:12:00+00:00     389447      25511             NaN
# 3   2024-05-10 15:30:41+00:00     328525      16764             NaN
# 4   2024-05-07 16:03:07+00:00     281947      16116             NaN
# ..                        ...        ...        ...             ...
# 489 2019-02-14 10:36:48+00:00      59320       3793             NaN
# 490 2019-01-27 09:48:43+00:00      52570       2972             NaN
# 491 2019-01-19 12:18:06+00:00      68160       3753             NaN
# 492 2019-01-13 00:02:52+00:00      85857       4122             NaN
# 493 2019-01-06 16:50:35+00:00     180960       8832             NaN
#
#      commentCount  duration definition caption pushblishDayName  \
# 0            3699  PT29M51S         hd    true           Sunday
# 1             480      PT1M         hd   false           Friday
# 2            3011   PT29M8S         hd    true           Sunday
# 3             789  PT23M51S         hd    true           Friday
# 4             665  PT24M53S         hd    true          Tuesday
# ..            ...       ...        ...     ...              ...
# 489           177    PT6M9S         hd   false         Thursday
# 490           168    PT7M4S         hd   false           Sunday
# 491           208  PT10M10S         hd   false         Saturday
# 492           205   PT9M42S         hd   false           Sunday
# 493           514   PT8M18S         hd   false           Sunday
#
#        durationSecs
# 0   0 days 00:29:51
# 1   0 days 00:01:00
# 2   0 days 00:29:08
# 3   0 days 00:23:51
# 4   0 days 00:24:53
# ..              ...
# 489 0 days 00:06:09
# 490 0 days 00:07:04
# 491 0 days 00:10:10
# 492 0 days 00:09:42
# 493 0 days 00:08:18
#
# [494 rows x 15 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id       channelTitle  \
# 0    imT2c4Efoxc  WildLens by Abrar
# 1    kVqAeo6k6b0  WildLens by Abrar
# 2    VkKRL-QMdm0  WildLens by Abrar
# 3    YufZFo44fOg  WildLens by Abrar
# 4    vsmkR_DAfjY  WildLens by Abrar
# ..           ...                ...
# 489  kWoEs6vNO94  WildLens by Abrar
# 490  8jcxfV3zarE  WildLens by Abrar
# 491  jbPyvT78XMQ  WildLens by Abrar
# 492  7vganh6--M8  WildLens by Abrar
# 493  lJv4UMQOcTw  WildLens by Abrar
#
#                                                  title  \
# 0    My Nightmare Experience with Lahore Airport Cu...
# 1    Traveling Around The World on Bike #wildlensby...
# 2    Cape of Good Hope and End of Africa Series 🇿🇦 ...
# 3    Finally Arrived in Cape Town the Most Beautifu...
# 4    The Journey is Getting tough as I get Closer t...
# ..                                                 ...
# 489                             Hallstatt Austria Vlog
# 490  Lapland one last Arctic Adventure Vlog 04 (Urd...
# 491  Lapland Chasing the dream (part 03) Vlog 03 | ...
# 492  Lapland Winter Wilderness Adventure (Part 02) ...
# 493        Lapland Winter Wonderland (part 01) Vlog 01
#
#                                            description  \
# 0    Instagram: https://www.instagram.com/WildLensB...
# 1    Imagine a life bursting with color – new skill...
# 2    Instagram: https://www.instagram.com/WildLensB...
# 3    Instagram: https://www.instagram.com/WildLensB...
# 4    Instagram: https://www.instagram.com/WildLensB...
# ..                                                 ...
# 489  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 490  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 491  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 492  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
# 493  Music: \nArtlist: https://bit.ly/3bsuF3I\n\n*A...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 489  [Hallstatt, Austria, Salzburg, Hallstatt Austr...
# 490  [Lapland, Finland, Lapland finland, lapland tr...
# 491  [Finland, Lapland, Lapland finland, Riisituntu...
# 492  [Lapland, Finland, Pakistanivlogger, Urduvlogs...
# 493  [Lapland, Finland, Syote, Urduvlogs, winter, p...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-06-23 14:46:43+00:00     614215      24110             NaN
# 1   2024-05-24 14:00:38+00:00     128516      13678             NaN
# 2   2024-05-12 16:12:00+00:00     389447      25511             NaN
# 3   2024-05-10 15:30:41+00:00     328525      16764             NaN
# 4   2024-05-07 16:03:07+00:00     281947      16116             NaN
# ..                        ...        ...        ...             ...
# 489 2019-02-14 10:36:48+00:00      59320       3793             NaN
# 490 2019-01-27 09:48:43+00:00      52570       2972             NaN
# 491 2019-01-19 12:18:06+00:00      68160       3753             NaN
# 492 2019-01-13 00:02:52+00:00      85857       4122             NaN
# 493 2019-01-06 16:50:35+00:00     180960       8832             NaN
#
#      commentCount  duration definition caption pushblishDayName  \
# 0            3699  PT29M51S         hd    true           Sunday
# 1             480      PT1M         hd   false           Friday
# 2            3011   PT29M8S         hd    true           Sunday
# 3             789  PT23M51S         hd    true           Friday
# 4             665  PT24M53S         hd    true          Tuesday
# ..            ...       ...        ...     ...              ...
# 489           177    PT6M9S         hd   false         Thursday
# 490           168    PT7M4S         hd   false           Sunday
# 491           208  PT10M10S         hd   false         Saturday
# 492           205   PT9M42S         hd   false           Sunday
# 493           514   PT8M18S         hd   false           Sunday
#
#        durationSecs  tagCount
# 0   0 days 00:29:51         0
# 1   0 days 00:01:00         0
# 2   0 days 00:29:08         0
# 3   0 days 00:23:51         0
# 4   0 days 00:24:53         0
# ..              ...       ...
# 489 0 days 00:06:09        12
# 490 0 days 00:07:04        25
# 491 0 days 00:10:10        27
# 492 0 days 00:09:42        18
# 493 0 days 00:08:18        30
#
# [494 rows x 16 columns]

# %% [markdown]
# ## Analysis: Best performing videos

# %%
import warnings
warnings.filterwarnings("ignore")
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ## Worst performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ## View distribution per video

# %%
sns.violinplot(video_df['viewCount'])
# Out:
# <Axes: >

# %% [markdown]
# ## Views vs. likes and comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# ## Video duration

# %%
# # Increase the figure size
# plt.figure(figsize=(10, 6))  # Adjust figsize as per your preference

# # Plot the histogram with adjusted bins and color
# sns.histplot(data=video_df, x='durationSecs', bins=50, color='blue')

# # Set the x-axis limit to zoom in on frequencies up to 2500
# plt.xlim(0, 2500)


# # Display the plot
# plt.show()
