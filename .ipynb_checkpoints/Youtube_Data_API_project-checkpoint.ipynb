# %%
api_key = "AIzaSyC9IQS-O5xgXapMEv9HC-1gfSyYAlX9gmI"

# %%
channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']

# %%
#pip install isodate
# Out:
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: six in c:\users\anaum\anaconda3\lib\site-packages (from isodate) (1.16.0)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: isodate
# Successfully installed isodate-0.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON

# %%
# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client

youtube = build(api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
playlist_id = "UUoOae5nYA7VqaXzerajD0lg"

# %%
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
def get_video_details(youtube, video_ids):
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }

            video_info = {}
            video_info['video_id'] = video['id']

            # print(video_info)
            # print(stats_to_keep.keys())

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']

# %%
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
video_df.dtypes
# Out:
# video_id           object
# channelTitle       object
# title              object
# description        object
# tags               object
# publishedAt        object
# viewCount           int64
# likeCount           int64
# favouriteCount    float64
# commentCount        int64
# duration           object
# definition         object
# caption            object
# dtype: object

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    eBVlVfAMtWc   Ali Abdaal
# 1    wD9hMYbijDA   Ali Abdaal
# 2    jAPPP7SE824   Ali Abdaal
# 3    HKGAzzqkfWM   Ali Abdaal
# 4    lrZQz2O91JY   Ali Abdaal
# ..           ...          ...
# 964  7APfFjfnNBc   Ali Abdaal
# 965  gBpBLTSCb4s   Ali Abdaal
# 966  Va0tSdPADpA   Ali Abdaal
# 967  XJHM0fEH3ss   Ali Abdaal
# 968  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0     My honest advice to someone who’s doing too much
# 1    If I Wanted to Make $10,000 as a Student, I'd ...
# 2            Level Up as If You Were in a Video Game 🎮
# 3            The Thing That Made Me More Productive ⚡️
# 4      What I Learned on My Personal Finance Journey 💰
# ..                                                 ...
# 964  Payphone (Maroon 5) - Katherine Macfarland & A...
# 965            6med UKCAT Crash Course - In a Nutshell
# 966             6med BMAT Crash Course - In a Nutshell
# 967  Rolling in the Deep (Adele) - Duranka Perera &...
# 968           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    Head over to Brilliant for a 30 day free trial...
# 1    Use the promo code ALI to get a free share wor...
# 2    Check out my New York Times bestselling book a...
# 3    Check out my New York Times bestselling book a...
# 4    Check out my New York Times bestselling book a...
# ..                                                 ...
# 964  First cover of 2017! We both love this song, s...
# 965  The 6med UKCAT Crash Course is the most effect...
# 966  The 6med BMAT Crash Course is the most effecti...
# 967  Our first 'proper' video! One of our all-time ...
# 968  First attempt at playing around with this sort...
#
#                                                   tags  \
# 0                              [Ali Abdaal, Ali abdal]
# 1    [Ali Abdaal, Ali abdal, high income skills, ho...
# 2                              [Ali Abdaal, Ali abdal]
# 3                              [Ali Abdaal, Ali abdal]
# 4                              [Ali Abdaal, Ali abdal]
# ..                                                 ...
# 964        [payphone, maroon 5, acoustic cover, cover]
# 965            ed, medical school, ukcat, medicine]
# 966           [BMAT, 6med, medicine, medical students]
# 967      [rolling in the deep, adele, cover, acoustic]
# 968                                               None
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-07-12 13:00:43+00:00      21258       1305             NaN
# 1   2024-07-09 13:01:05+00:00     136430       6264             NaN
# 2   2024-07-09 12:00:52+00:00      12159        984             NaN
# 3   2024-07-08 12:00:13+00:00      19086       1119             NaN
# 4   2024-07-07 12:00:57+00:00      18370       1530             NaN
# ..                        ...        ...        ...             ...
# 964 2017-01-04 23:13:51+00:00      96512       2327             NaN
# 965 2016-05-09 18:45:18+00:00      17382        132             NaN
# 966 2016-04-27 09:04:49+00:00      42417        305             NaN
# 967 2016-04-05 09:05:29+00:00      65957        793             NaN
# 968 2016-03-27 19:30:11+00:00     141107       1676             NaN
#
#      commentCount  duration definition caption pushblishDayName
# 0             194   PT23M3S         hd   false           Friday
# 1             324  PT14M34S         hd   false          Tuesday
# 2             108     PT47S         hd   false          Tuesday
# 3              48     PT38S         hd   false           Monday
# 4             120     PT52S         hd   false           Sunday
# ..            ...       ...        ...     ...              ...
# 964           150   PT2M35S         hd   false        Wednesday
# 965             6   PT2M11S         hd   false           Monday
# 966            10   PT2M18S         hd   false        Wednesday
# 967            40   PT2M29S         hd   false          Tuesday
# 968           163   PT1M43S         hd   false           Sunday
#
# [969 rows x 14 columns]

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    eBVlVfAMtWc   Ali Abdaal
# 1    wD9hMYbijDA   Ali Abdaal
# 2    jAPPP7SE824   Ali Abdaal
# 3    HKGAzzqkfWM   Ali Abdaal
# 4    lrZQz2O91JY   Ali Abdaal
# ..           ...          ...
# 964  7APfFjfnNBc   Ali Abdaal
# 965  gBpBLTSCb4s   Ali Abdaal
# 966  Va0tSdPADpA   Ali Abdaal
# 967  XJHM0fEH3ss   Ali Abdaal
# 968  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0     My honest advice to someone who’s doing too much
# 1    If I Wanted to Make $10,000 as a Student, I'd ...
# 2            Level Up as If You Were in a Video Game 🎮
# 3            The Thing That Made Me More Productive ⚡️
# 4      What I Learned on My Personal Finance Journey 💰
# ..                                                 ...
# 964  Payphone (Maroon 5) - Katherine Macfarland & A...
# 965            6med UKCAT Crash Course - In a Nutshell
# 966             6med BMAT Crash Course - In a Nutshell
# 967  Rolling in the Deep (Adele) - Duranka Perera &...
# 968           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    Head over to Brilliant for a 30 day free trial...
# 1    Use the promo code ALI to get a free share wor...
# 2    Check out my New York Times bestselling book a...
# 3    Check out my New York Times bestselling book a...
# 4    Check out my New York Times bestselling book a...
# ..                                                 ...
# 964  First cover of 2017! We both love this song, s...
# 965  The 6med UKCAT Crash Course is the most effect...
# 966  The 6med BMAT Crash Course is the most effecti...
# 967  Our first 'proper' video! One of our all-time ...
# 968  First attempt at playing around with this sort...
#
#                                                   tags  \
# 0                              [Ali Abdaal, Ali abdal]
# 1    [Ali Abdaal, Ali abdal, high income skills, ho...
# 2                              [Ali Abdaal, Ali abdal]
# 3                              [Ali Abdaal, Ali abdal]
# 4                              [Ali Abdaal, Ali abdal]
# ..                                                 ...
# 964        [payphone, maroon 5, acoustic cover, cover]
# 965            ed, medical school, ukcat, medicine]
# 966           [BMAT, 6med, medicine, medical students]
# 967      [rolling in the deep, adele, cover, acoustic]
# 968                                               None
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-07-12 13:00:43+00:00      21258       1305             NaN
# 1   2024-07-09 13:01:05+00:00     136430       6264             NaN
# 2   2024-07-09 12:00:52+00:00      12159        984             NaN
# 3   2024-07-08 12:00:13+00:00      19086       1119             NaN
# 4   2024-07-07 12:00:57+00:00      18370       1530             NaN
# ..                        ...        ...        ...             ...
# 964 2017-01-04 23:13:51+00:00      96512       2327             NaN
# 965 2016-05-09 18:45:18+00:00      17382        132             NaN
# 966 2016-04-27 09:04:49+00:00      42417        305             NaN
# 967 2016-04-05 09:05:29+00:00      65957        793             NaN
# 968 2016-03-27 19:30:11+00:00     141107       1676             NaN
#
#      commentCount  duration definition caption pushblishDayName  \
# 0             194   PT23M3S         hd   false           Friday
# 1             324  PT14M34S         hd   false          Tuesday
# 2             108     PT47S         hd   false          Tuesday
# 3              48     PT38S         hd   false           Monday
# 4             120     PT52S         hd   false           Sunday
# ..            ...       ...        ...     ...              ...
# 964           150   PT2M35S         hd   false        Wednesday
# 965             6   PT2M11S         hd   false           Monday
# 966            10   PT2M18S         hd   false        Wednesday
# 967            40   PT2M29S         hd   false          Tuesday
# 968           163   PT1M43S         hd   false           Sunday
#
#        durationSecs
# 0   0 days 00:23:03
# 1   0 days 00:14:34
# 2   0 days 00:00:47
# 3   0 days 00:00:38
# 4   0 days 00:00:52
# ..              ...
# 964 0 days 00:02:35
# 965 0 days 00:02:11
# 966 0 days 00:02:18
# 967 0 days 00:02:29
# 968 0 days 00:01:43
#
# [969 rows x 15 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    eBVlVfAMtWc   Ali Abdaal
# 1    wD9hMYbijDA   Ali Abdaal
# 2    jAPPP7SE824   Ali Abdaal
# 3    HKGAzzqkfWM   Ali Abdaal
# 4    lrZQz2O91JY   Ali Abdaal
# ..           ...          ...
# 964  7APfFjfnNBc   Ali Abdaal
# 965  gBpBLTSCb4s   Ali Abdaal
# 966  Va0tSdPADpA   Ali Abdaal
# 967  XJHM0fEH3ss   Ali Abdaal
# 968  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0     My honest advice to someone who’s doing too much
# 1    If I Wanted to Make $10,000 as a Student, I'd ...
# 2            Level Up as If You Were in a Video Game 🎮
# 3            The Thing That Made Me More Productive ⚡️
# 4      What I Learned on My Personal Finance Journey 💰
# ..                                                 ...
# 964  Payphone (Maroon 5) - Katherine Macfarland & A...
# 965            6med UKCAT Crash Course - In a Nutshell
# 966             6med BMAT Crash Course - In a Nutshell
# 967  Rolling in the Deep (Adele) - Duranka Perera &...
# 968           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    Head over to Brilliant for a 30 day free trial...
# 1    Use the promo code ALI to get a free share wor...
# 2    Check out my New York Times bestselling book a...
# 3    Check out my New York Times bestselling book a...
# 4    Check out my New York Times bestselling book a...
# ..                                                 ...
# 964  First cover of 2017! We both love this song, s...
# 965  The 6med UKCAT Crash Course is the most effect...
# 966  The 6med BMAT Crash Course is the most effecti...
# 967  Our first 'proper' video! One of our all-time ...
# 968  First attempt at playing around with this sort...
#
#                                                   tags  \
# 0                              [Ali Abdaal, Ali abdal]
# 1    [Ali Abdaal, Ali abdal, high income skills, ho...
# 2                              [Ali Abdaal, Ali abdal]
# 3                              [Ali Abdaal, Ali abdal]
# 4                              [Ali Abdaal, Ali abdal]
# ..                                                 ...
# 964        [payphone, maroon 5, acoustic cover, cover]
# 965            ed, medical school, ukcat, medicine]
# 966           [BMAT, 6med, medicine, medical students]
# 967      [rolling in the deep, adele, cover, acoustic]
# 968                                               None
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-07-12 13:00:43+00:00      21258       1305             NaN
# 1   2024-07-09 13:01:05+00:00     136430       6264             NaN
# 2   2024-07-09 12:00:52+00:00      12159        984             NaN
# 3   2024-07-08 12:00:13+00:00      19086       1119             NaN
# 4   2024-07-07 12:00:57+00:00      18370       1530             NaN
# ..                        ...        ...        ...             ...
# 964 2017-01-04 23:13:51+00:00      96512       2327             NaN
# 965 2016-05-09 18:45:18+00:00      17382        132             NaN
# 966 2016-04-27 09:04:49+00:00      42417        305             NaN
# 967 2016-04-05 09:05:29+00:00      65957        793             NaN
# 968 2016-03-27 19:30:11+00:00     141107       1676             NaN
#
#      commentCount  duration definition caption pushblishDayName  \
# 0             194   PT23M3S         hd   false           Friday
# 1             324  PT14M34S         hd   false          Tuesday
# 2             108     PT47S         hd   false          Tuesday
# 3              48     PT38S         hd   false           Monday
# 4             120     PT52S         hd   false           Sunday
# ..            ...       ...        ...     ...              ...
# 964           150   PT2M35S         hd   false        Wednesday
# 965             6   PT2M11S         hd   false           Monday
# 966            10   PT2M18S         hd   false        Wednesday
# 967            40   PT2M29S         hd   false          Tuesday
# 968           163   PT1M43S         hd   false           Sunday
#
#        durationSecs  tagCount
# 0   0 days 00:23:03         2
# 1   0 days 00:14:34        19
# 2   0 days 00:00:47         2
# 3   0 days 00:00:38         2
# 4   0 days 00:00:52         2
# ..              ...       ...
# 964 0 days 00:02:35         4
# 965 0 days 00:02:11         4
# 966 0 days 00:02:18         4
# 967 0 days 00:02:29         4
# 968 0 days 00:01:43         0
#
# [969 rows x 16 columns]

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))
